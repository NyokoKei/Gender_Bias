# %%
import pandas as pd
import numpy as np
import re
from iso639 import Lang

# %%
google_translate = pd.read_csv('data/google_translate.csv', index_col='No')
deepl = pd.read_csv('data/DeepL.csv', index_col='No')
gpt = pd.read_csv('data/gpt.csv', index_col='No')
gemini = pd.read_csv('data/gemini.csv', index_col='No')
copilot = pd.read_csv('data/copilot.csv', index_col='No')
claude = pd.read_csv('data/claude.csv', index_col='No')

gender = pd.read_csv('data/GrammaticalGender.csv')
gender = gender.sort_values(by='Language')

# %%
def clean_language_name(name):
    return re.sub(r'\s*\(.*?\)', '', name).strip()


google_translate['Languages'] = google_translate['Languages'].apply(clean_language_name)
deepl['Language'] = deepl['Language'].apply(clean_language_name)
gpt['Language'] = gpt['Language'].apply(clean_language_name)
gemini['Language'] = gemini['Language'].apply(clean_language_name)
copilot['Language'] = copilot['Language'].apply(clean_language_name)
claude['Language'] = claude['Language'].apply(clean_language_name)

# %%
languages = np.array(list(set(set(google_translate.Languages) | set(deepl.Language) | set(gpt.Language) | set(gemini.Language) | set(copilot.Language) | set(claude.Language))))
No = np.array([i+1 for i in range(len(languages))])

languages.sort()

df = {'Language': languages}
df = pd.DataFrame(df)


df['GoogleTranslate'] = df['Language'].isin(google_translate['Languages']).astype(int)
df['DeepL'] = df['Language'].isin(deepl['Language']).astype(int)
df['GPT'] = df['Language'].isin(gpt['Language']).astype(int)
df['Gemini'] = df['Language'].isin(gemini['Language']).astype(int)
df['Copilot'] = df['Language'].isin(copilot['Language']).astype(int)
df['Claude'] = df['Language'].isin(claude['Language']).astype(int)

df['GrammaticalGender'] = df['Language'].isin(gender['Language']).astype(int)


df = df.sort_values(by='Language')
df
# Out:
#          Language  GoogleTranslate  DeepL  GPT  Gemini  Copilot  Claude  \
# 0          Abkhaz                1      0    0       0        0       0
# 1        Acehnese                1      0    0       0        0       0
# 2          Acholi                1      0    0       0        0       0
# 3            Afar                1      0    0       0        0       0
# 4       Afrikaans                1      0    1       1        0       0
# ..            ...              ...    ...  ...     ...      ...     ...
# 234       Yiddish                1      0    1       0        0       0
# 235        Yoruba                1      0    1       1        0       0
# 236  Yucatec Maya                1      0    0       0        0       0
# 237       Zapotec                1      0    0       0        0       0
# 238          Zulu                1      0    1       1        0       0
#
#      GrammaticalGender
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0
# ..                 ...
# 234                  1
# 235                  0
# 236                  0
# 237                  0
# 238                  0
#
# [239 rows x 8 columns]

# %%
df[df['GrammaticalGender'] == 1]
# Out:
#        Language  GoogleTranslate  DeepL  GPT  Gemini  Copilot  Claude  \
# 3          Afar                1      0    0       0        0       0
# 5      Albanian                1      0    1       1        0       0
# 7       Amharic                1      0    1       0        0       0
# 8        Arabic                1      1    1       1        1       1
# 24   Belarusian                1      0    1       1        0       0
# ..          ...              ...    ...  ...     ...      ...     ...
# 222   Ukrainian                1      1    1       1        1       1
# 223        Urdu                1      0    1       1        0       1
# 227    Venetian                1      0    0       0        0       0
# 230       Welsh                1      0    1       1        1       0
# 234     Yiddish                1      0    1       0        0       0
#
#      GrammaticalGender
# 3                    1
# 5                    1
# 7                    1
# 8                    1
# 24                   1
# ..                 ...
# 222                  1
# 223                  1
# 227                  1
# 230                  1
# 234                  1
#
# [62 rows x 8 columns]

# %%
df.insert(0, 'Code', None)

for index, row in df.iterrows():
    if row['Code'] is None:  
        try:
            temp = Lang(row['Language']).pt3
            df.loc[df['Language'] == row['Language'], 'Code'] = temp
        except:
            continue  # Skip to the next iteration if there's an error
df
# Out:
#      Code      Language  GoogleTranslate  DeepL  GPT  Gemini  Copilot  Claude  \
# 0    None        Abkhaz                1      0    0       0        0       0
# 1    None      Acehnese                1      0    0       0        0       0
# 2    None        Acholi                1      0    0       0        0       0
# 3     aar          Afar                1      0    0       0        0       0
# 4     afr     Afrikaans                1      0    1       1        0       0
# ..    ...           ...              ...    ...  ...     ...      ...     ...
# 234   yid       Yiddish                1      0    1       0        0       0
# 235   yor        Yoruba                1      0    1       1        0       0
# 236   yua  Yucatec Maya                1      0    0       0        0       0
# 237   zap       Zapotec                1      0    0       0        0       0
# 238   zul          Zulu                1      0    1       1        0       0
#
#      GrammaticalGender
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0
# ..                 ...
# 234                  1
# 235                  0
# 236                  0
# 237                  0
# 238                  0
#
# [239 rows x 9 columns]

# %%
none_list = df[df['Code'].isnull()]['Language'].tolist()
print(len(none_list), none_list)
# Out:
# 39 ['Abkhaz', 'Acehnese', 'Acholi', 'Avar', 'Buryat', 'Cantonese', 'Frisian', 'Fulani', 'Greek', 'Ilocano', 'Jamaican Patois', 'Jingpo', 'Kiga', 'Kikongo', 'Kituba', 'Kokborok', 'Luganda', 'Luo', 'Makassar', 'Marwadi', 'Mauritian Creole', 'Meadow Mari', 'Meiteilon', 'Mizo', 'Myanmar', 'NKo', 'Nahuatl', 'Ndebele', 'Nepalbhasa', 'Occitan', 'Qʼeqchiʼ', 'Romani', 'Sami', 'Scots Gaelic', 'Sesotho', 'Seychellois Creole', 'Tamazight', 'Tongan', 'Tuvan']

# %%
language_codes = {
    'Abkhaz': 'abk',
    'Acehnese': 'ace',
    'Acholi': 'ach',
    'Avar': 'ava',
    'Buryat': 'bxm',
    'Cantonese': 'yue',
    'Frisian': 'frr',
    'Fulani': 'ful',
    'Greek': 'ell',
    'Ilocano': 'ilo',
    'Jamaican Patois': 'jam',
    'Jingpo': 'kac',
    'Kiga': 'cgg',
    'Kikongo': 'kwy',
    'Kituba': 'ktu',
    'Kokborok': 'trp',
    'Luganda': 'lug',
    'Luo': 'luo',
    'Makassar': 'mak',
    'Marwadi': 'rwr',
    'Mauritian Creole': 'mfe',
    'Meadow Mari': 'mhr',
    'Meiteilon': 'mni',
    'Mizo': 'lus',
    'Myanmar': 'mya',
    'NKo': 'nqo',
    'Nahuatl': 'nhe',
    'Ndebele': 'nde',
    'Nepalbhasa': 'new',
    'Occitan': 'oci',
    'Qʼeqchiʼ': 'kek',
    'Romani': 'rom',
    'Sami': 'sme',
    'Scots Gaelic': 'gla',
    'Sesotho': 'sot',
    'Seychellois Creole': 'crs',
    'Tamazight': 'tzm',
    'Tongan': 'ton',
    'Tuvan': 'tyv'
}


df['Code'] = df['Code'].fillna(df['Language'].map(language_codes))
df
# Out:
#     Code      Language  GoogleTranslate  DeepL  GPT  Gemini  Copilot  Claude  \
# 0    abk        Abkhaz                1      0    0       0        0       0
# 1    ace      Acehnese                1      0    0       0        0       0
# 2    ach        Acholi                1      0    0       0        0       0
# 3    aar          Afar                1      0    0       0        0       0
# 4    afr     Afrikaans                1      0    1       1        0       0
# ..   ...           ...              ...    ...  ...     ...      ...     ...
# 234  yid       Yiddish                1      0    1       0        0       0
# 235  yor        Yoruba                1      0    1       1        0       0
# 236  yua  Yucatec Maya                1      0    0       0        0       0
# 237  zap       Zapotec                1      0    0       0        0       0
# 238  zul          Zulu                1      0    1       1        0       0
#
#      GrammaticalGender
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0
# ..                 ...
# 234                  1
# 235                  0
# 236                  0
# 237                  0
# 238                  0
#
# [239 rows x 9 columns]

# %%
none_list = df[df['Code'].isnull()]['Language'].tolist()
print(len(none_list), none_list)
# Out:
# 0 []

# %% [markdown]
# ### Code-Language-Family

# %%
#https://github.com/dw-data/ai-languages/blob/main/README.md
df2 = pd.read_excel('data/Data.xlsx', sheet_name="Ethnologue", header=2)
df2.sample(10)
# Out:
#               users       DLS       family-link  \
# 2881  Less than 10K     Still     Sign language
# 3679      10K to 1M     Still    Austro-Asiatic
# 5771            NaN       NaN     Sign language
# 2912  Less than 10K     Still  Trans-New Guinea
# 1996            NaN     Still     Sign language
# 3375      10K to 1M  Emerging      Sino-Tibetan
# 2655  Less than 10K     Still      Afro-Asiatic
# 1641  Less than 10K     Still      Austronesian
# 5426            NaN     Still        Australian
# 2852      10K to 1M     Still         Dravidian
#
#                                family-link-href languagecode  \
# 2881     https://www.ethnologue.com/subgroup/2/          kgi
# 3679   https://www.ethnologue.com/subgroup/231/          lyg
# 5771     https://www.ethnologue.com/subgroup/2/          sqx
# 2912  https://www.ethnologue.com/subgroup/1038/          khs
# 1996     https://www.ethnologue.com/subgroup/2/          gds
# 3375   https://www.ethnologue.com/subgroup/236/          lbf
# 2655    https://www.ethnologue.com/subgroup/31/          jie
# 1641   https://www.ethnologue.com/subgroup/447/          dro
# 5426    https://www.ethnologue.com/subgroup/87/          rxd
# 2852  https://www.ethnologue.com/subgroup/1265/          kfb
#
#                              languagelink-href    vitality   languagecountry  \
# 2881  https://www.ethnologue.com/language/kgi/  Endangered          Malaysia
# 3679  https://www.ethnologue.com/language/lyg/  Endangered             India
# 5771  https://www.ethnologue.com/language/sqx/      Stable            Israel
# 2912  https://www.ethnologue.com/language/khs/      Stable  Papua New Guinea
# 1996  https://www.ethnologue.com/language/gds/  Endangered             Nepal
# 3375  https://www.ethnologue.com/language/lbf/  Endangered             India
# 2655  https://www.ethnologue.com/language/jie/  Endangered           Nigeria
# 1641  https://www.ethnologue.com/language/dro/  Endangered          Malaysia
# 5426  https://www.ethnologue.com/language/rxd/     Extinct         Australia
# 2852  https://www.ethnologue.com/language/kfb/      Stable             India
#
#                    languagename      lat      long
# 2881     Selangor Sign Language   3.3061  101.4956
# 3679                   Lyngngam  25.8531   91.8063
# 5771  Kufr Qassem Sign Language  31.9175   35.2228
# 2912                      Kasua  -6.7219  142.9542
# 1996     Ghandruk Sign Language  28.3792   83.8013
# 3375                     Tinani  32.3992   77.4870
# 2655                      Jilbe  11.8014   14.5781
# 1641         Melanau, Daro-Matu   2.4443  111.5872
# 5426                     Ngardi -21.0231  129.0308
# 2852        Northwestern Kolami  20.0626   78.0913

# %%
langs = df2[['languagecode', 'languagename', 'family-link']].copy()
langs.rename(columns={'languagecode': 'Code', 
                      'languagename': 'Language', 
                      'family-link': 'Family'}, inplace=True)
langs.to_csv('data/languages.csv', index=False)
langs.sample(10)
# Out:
#      Code              Language              Family
# 1445  dak                Dakota     Siouan-Catawban
# 2090  gmm         Gbaya-Mbodomo         Niger-Congo
# 2334  hmm  Miao, Central Mashan          Hmong-Mien
# 6311  tsy   Tebul Sign Language       Sign language
# 1740  eiv               Askopan  North Bougainville
# 7077  xwe            Gbe, Xwela         Niger-Congo
# 5505  sdn  Sardinian, Gallurese       Indo-European
# 1303  cob         Chicomuceltec               Mayan
# 6370  tvt           Naga, Tutsa        Sino-Tibetan
# 4311  nam       Ngan’gityemerri          Australian

# %%
df = df.merge(langs[['Code', 'Family']], on='Code', how='left')
df
# Out:
#     Code      Language  GoogleTranslate  DeepL  GPT  Gemini  Copilot  Claude  \
# 0    abk        Abkhaz                1      0    0       0        0       0
# 1    ace      Acehnese                1      0    0       0        0       0
# 2    ach        Acholi                1      0    0       0        0       0
# 3    aar          Afar                1      0    0       0        0       0
# 4    afr     Afrikaans                1      0    1       1        0       0
# ..   ...           ...              ...    ...  ...     ...      ...     ...
# 234  yid       Yiddish                1      0    1       0        0       0
# 235  yor        Yoruba                1      0    1       1        0       0
# 236  yua  Yucatec Maya                1      0    0       0        0       0
# 237  zap       Zapotec                1      0    0       0        0       0
# 238  zul          Zulu                1      0    1       1        0       0
#
#      GrammaticalGender         Family
# 0                    0  Abkhaz-Adyghe
# 1                    0   Austronesian
# 2                    0   Nilo-Saharan
# 3                    1   Afro-Asiatic
# 4                    0  Indo-European
# ..                 ...            ...
# 234                  1            NaN
# 235                  0    Niger-Congo
# 236                  0          Mayan
# 237                  0            NaN
# 238                  0    Niger-Congo
#
# [239 rows x 10 columns]

# %%
none_list = df[df['Family'].isna()]['Code'].tolist()
print(len(none_list), none_list)
# Out:
# 36 ['sqi', 'ara', 'aym', 'aze', 'bal', 'bik', 'zho', 'din', 'doi', 'est', 'ful', 'grn', 'hmn', 'kau', 'kaz', 'kom', 'kok', 'kur', 'kir', 'lav', 'mlg', 'msa', 'mon', 'nep', 'orm', 'pus', 'fas', 'que', 'rom', 'swa', 'tyv', 'twi', 'uzb', 'sah', 'yid', 'zap']

# %%
language_families = {
    'sqi': 'Indo-European',
    'ara': 'Afro-Asiatic',
    'aym': 'Aymaran',
    'aze': 'Turkic',
    'bal': 'Indo-European',
    'bik': 'Austronesian',
    'zho': 'Sino-Tibetan',
    'din': 'Nilo-Saharan',
    'doi': 'Indo-European',
    'est': 'Uralic',
    'ful': 'Niger-Congo',
    'grn': 'Tupian',
    'hmn': 'Hmong-Mien',
    'kau': 'Nilo-Saharan',
    'kaz': 'Turkic',
    'kom': 'Uralic',
    'kok': 'Indo-European',
    'kur': 'Indo-European',
    'kir': 'Turkic',
    'lav': 'Indo-European',
    'mlg': 'Austronesian',
    'msa': 'Austronesian',
    'mon': 'Mongolic',
    'nep': 'Indo-European',
    'orm': 'Afro-Asiatic',
    'pus': 'Indo-European',
    'fas': 'Indo-Iranian',
    'que': 'Quechuan',
    'rom': 'Indo-European',
    'swa': 'Niger-Congo',
    'tyv': 'Turkic',
    'twi': 'Kwa',
    'uzb': 'Turkic',
    'sah': 'Turkic',
    'yid': 'Indo-European',
    'zap': 'Otomanguean'
}


df['Family'] = df['Family'].fillna(df['Code'].map(language_families))
df
# Out:
#     Code      Language  GoogleTranslate  DeepL  GPT  Gemini  Copilot  Claude  \
# 0    abk        Abkhaz                1      0    0       0        0       0
# 1    ace      Acehnese                1      0    0       0        0       0
# 2    ach        Acholi                1      0    0       0        0       0
# 3    aar          Afar                1      0    0       0        0       0
# 4    afr     Afrikaans                1      0    1       1        0       0
# ..   ...           ...              ...    ...  ...     ...      ...     ...
# 234  yid       Yiddish                1      0    1       0        0       0
# 235  yor        Yoruba                1      0    1       1        0       0
# 236  yua  Yucatec Maya                1      0    0       0        0       0
# 237  zap       Zapotec                1      0    0       0        0       0
# 238  zul          Zulu                1      0    1       1        0       0
#
#      GrammaticalGender         Family
# 0                    0  Abkhaz-Adyghe
# 1                    0   Austronesian
# 2                    0   Nilo-Saharan
# 3                    1   Afro-Asiatic
# 4                    0  Indo-European
# ..                 ...            ...
# 234                  1  Indo-European
# 235                  0    Niger-Congo
# 236                  0          Mayan
# 237                  0    Otomanguean
# 238                  0    Niger-Congo
#
# [239 rows x 10 columns]

# %%
none_list = df[df['Family'].isna()]['Code'].tolist()
print(len(none_list), none_list)
# Out:
# 0 []

# %%
gender_df = df[df['GrammaticalGender'] == 1]
gender_df
# Out:
#     Code    Language  GoogleTranslate  DeepL  GPT  Gemini  Copilot  Claude  \
# 3    aar        Afar                1      0    0       0        0       0
# 5    sqi    Albanian                1      0    1       1        0       0
# 7    amh     Amharic                1      0    1       0        0       0
# 8    ara      Arabic                1      1    1       1        1       1
# 24   bel  Belarusian                1      0    1       1        0       0
# ..   ...         ...              ...    ...  ...     ...      ...     ...
# 222  ukr   Ukrainian                1      1    1       1        1       1
# 223  urd        Urdu                1      0    1       1        0       1
# 227  vec    Venetian                1      0    0       0        0       0
# 230  cym       Welsh                1      0    1       1        1       0
# 234  yid     Yiddish                1      0    1       0        0       0
#
#      GrammaticalGender         Family
# 3                    1   Afro-Asiatic
# 5                    1  Indo-European
# 7                    1   Afro-Asiatic
# 8                    1   Afro-Asiatic
# 24                   1  Indo-European
# ..                 ...            ...
# 222                  1  Indo-European
# 223                  1  Indo-European
# 227                  1  Indo-European
# 230                  1  Indo-European
# 234                  1  Indo-European
#
# [62 rows x 10 columns]

# %%
df.to_csv('data/result.csv', index=False)
gender_df.to_csv('data/result_gender.csv', index=False)
