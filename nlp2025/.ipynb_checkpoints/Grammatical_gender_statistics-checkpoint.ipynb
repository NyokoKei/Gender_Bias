# %%
import pandas as pd
from iso639 import Lang

# %%
df = pd.read_csv('source_data/grammatical-gender.csv') #From Wikipedia
df = df.sort_values(by='Language').reset_index(drop=True)

df
# Out:
#     Language
# 0       Afar
# 1       Agaw
# 2   Alamblak
# 3   Albanian
# 4    Amharic
# ..       ...
# 85     Welsh
# 86  Worrorra
# 87   Yiddish
# 88     Zande
# 89    Zazaki
#
# [90 rows x 1 columns]

# %%
df.insert(0, 'Code', None)
for index, row in df.iterrows():
    if row['Code'] is None:  
        try:
            temp = Lang(row['Language']).pt3
            df.loc[df['Language'] == row['Language'], 'Code'] = temp
        except:
            continue  # Skip to the next iteration if there's an error
df
# Out:
#     Code  Language
# 0    aar      Afar
# 1   None      Agaw
# 2    amp  Alamblak
# 3    sqi  Albanian
# 4    amh   Amharic
# ..   ...       ...
# 85   cym     Welsh
# 86   wro  Worrorra
# 87   yid   Yiddish
# 88  None     Zande
# 89   zza    Zazaki
#
# [90 rows x 2 columns]

# %%
none_list = df[df['Code'].isnull()]['Language'].tolist()
print(len(none_list), none_list)
# Out:
# 9 ['Agaw', 'Friulan', 'Greek', 'Kalaw Lagaw Ya', 'Occitan', 'Romani', 'Tamazight', 'Tuareg', 'Zande']

# %%
language_codes = {'Agaw': 'awn',
                 'Friulan': 'fur',
                 'Greek': 'ell',
                 'Kalaw Lagaw Ya': 'mwp',
                 'Occitan': 'oci',
                 'Romani': 'rom',
                 'Tamazight': 'zgh',
                 'Tuareg': 'tmh',
                 'Zande': 'zne'}

# %%
df['Code'] = df['Code'].fillna(df['Language'].map(language_codes))
df
# Out:
#    Code  Language
# 0   aar      Afar
# 1   awn      Agaw
# 2   amp  Alamblak
# 3   sqi  Albanian
# 4   amh   Amharic
# ..  ...       ...
# 85  cym     Welsh
# 86  wro  Worrorra
# 87  yid   Yiddish
# 88  zne     Zande
# 89  zza    Zazaki
#
# [90 rows x 2 columns]

# %%
df.to_csv('output_data/gramm_gend_code.csv', index=False)

# %%
# https://github.com/dw-data/ai-languages/blob/main/README.md
df2 = pd.read_excel('source_data/Data.xlsx', sheet_name="Ethnologue", header=2)
df2.sample(10)
# Out:
#               users       DLS        family-link  \
# 2800  Less than 10K     Still       Afro-Asiatic
# 7128      10K to 1M     Still        Niger-Congo
# 1368            NaN     Still    Miwok-Costanoan
# 1023  Less than 10K     Still  East Geelvink Bay
# 5108      10K to 1M     Still              Mayan
# 7372      10K to 1M     Still        Niger-Congo
# 720   Less than 10K  Emerging       Austronesian
# 4205  Less than 10K     Still       Austronesian
# 4619      10K to 1M     Still        Uto-Aztecan
# 7202  Less than 10K     Still         Torricelli
#
#                                family-link-href languagecode  \
# 2800    https://www.ethnologue.com/subgroup/31/          kcx
# 7128    https://www.ethnologue.com/subgroup/47/          ybl
# 1368  https://www.ethnologue.com/subgroup/3852/          csi
# 1023  https://www.ethnologue.com/subgroup/1397/          bvz
# 5108   https://www.ethnologue.com/subgroup/268/          poc
# 7372    https://www.ethnologue.com/subgroup/47/          zin
# 720    https://www.ethnologue.com/subgroup/447/          bjl
# 4205   https://www.ethnologue.com/subgroup/447/          mvt
# 4619  https://www.ethnologue.com/subgroup/1066/          npl
# 7202  https://www.ethnologue.com/subgroup/2211/          yll
#
#                              languagelink-href    vitality   languagecountry  \
# 2800  https://www.ethnologue.com/language/kcx/      Stable          Ethiopia
# 7128  https://www.ethnologue.com/language/ybl/      Stable           Nigeria
# 1368  https://www.ethnologue.com/language/csi/  Endangered     United States
# 1023  https://www.ethnologue.com/language/bvz/      Stable         Indonesia
# 5108  https://www.ethnologue.com/language/poc/  Endangered         Guatemala
# 7372  https://www.ethnologue.com/language/zin/  Endangered          Tanzania
# 720   https://www.ethnologue.com/language/bjl/      Stable  Papua New Guinea
# 4205  https://www.ethnologue.com/language/mvt/  Endangered           Vanuatu
# 4619  https://www.ethnologue.com/language/npl/      Stable            Mexico
# 7202  https://www.ethnologue.com/language/yll/      Stable  Papua New Guinea
#
#                       languagename      lat      long
# 2800               Kachama-Ganjule   6.3920   37.9304
# 7128                       Yukuben   6.8956    9.7954
# 1368                  Miwok, Coast  38.0005 -122.7255
# 1023                         Bauzi  -2.3979  137.5845
# 5108                       Poqomam  14.7325  -89.7380
# 7372                         Zinza  -2.6722   32.2130
# 720                           Bulu  -5.0601  150.0947
# 4205                     Mpotovoro -15.9128  167.2081
# 4619  Nahuatl, Southeastern Puebla  18.3769  -97.2526
# 7202                           Yil  -3.5043  142.2036

# %%
langs = df2[['languagecode', 'family-link', 'users', 'vitality', 'languagecountry', 'DLS']].copy()
langs.rename(columns={'languagecode': 'Code',  
                      'family-link': 'Family',
                      'users': 'Speaker',
                      'vitality': 'Vitality',
                      'languagecountry': 'Country',
                      'DLS': 'Digital Language Support'}, inplace=True)
langs.to_csv('output_data/languages.csv', index=False)
langs.sample(10)
# Out:
#      Code            Family        Speaker       Vitality  \
# 4688  nua      Austronesian  Less than 10K     Endangered
# 3293  kxo  Language isolate            NaN     Endangered
# 6168  tmd             Piawi  Less than 10K         Stable
# 5984  tcl      Sino-Tibetan            NaN     Endangered
# 6859  wxa      Unclassified      10K to 1M     Endangered
# 496   bac      Austronesian      10K to 1M         Stable
# 4472  nij      Austronesian      10K to 1M  Institutional
# 4539  nlo       Niger-Congo  Less than 10K         Stable
# 2830  kef       Niger-Congo  Less than 10K         Stable
# 6547  utr       Niger-Congo      10K to 1M         Stable
#
#                                Country Digital Language Support
# 4688                     New Caledonia                    Still
# 3293                            Brazil                    Still
# 6168                  Papua New Guinea                    Still
# 5984                           Myanmar                    Still
# 6859                             China                    Still
# 496                          Indonesia                    Still
# 4472                         Indonesia                    Still
# 4539  Democratic Republic of the Congo                    Still
# 2830                              Togo                    Still
# 6547                           Nigeria                    Still

# %%
df = df.merge(langs, on='Code', how='left')
df
# Out:
#    Code  Language         Family        Speaker       Vitality  \
# 0   aar      Afar   Afro-Asiatic       1M to 1B  Institutional
# 1   awn      Agaw   Afro-Asiatic      10K to 1M         Stable
# 2   amp  Alamblak          Sepik  Less than 10K     Endangered
# 3   sqi  Albanian            NaN            NaN            NaN
# 4   amh   Amharic   Afro-Asiatic       1M to 1B  Institutional
# ..  ...       ...            ...            ...            ...
# 85  cym     Welsh  Indo-European      10K to 1M  Institutional
# 86  wro  Worrorra     Australian            NaN     Endangered
# 87  yid   Yiddish            NaN            NaN            NaN
# 88  zne     Zande    Niger-Congo       1M to 1B  Institutional
# 89  zza    Zazaki            NaN            NaN            NaN
#
#                              Country Digital Language Support
# 0                           Ethiopia                 Emerging
# 1                           Ethiopia                 Emerging
# 2                   Papua New Guinea                    Still
# 3                                NaN                      NaN
# 4                           Ethiopia                    Vital
# ..                               ...                      ...
# 85                    United Kingdom                    Vital
# 86                         Australia                    Still
# 87                               NaN                      NaN
# 88  Democratic Republic of the Congo                    Still
# 89                               NaN                      NaN
#
# [90 rows x 7 columns]

# %%
nan_info = df.isna().sum()
nan_info
# Out:
# Code                         0
# Language                     0
# Family                      13
# Speaker                     18
# Vitality                    13
# Country                     13
# Digital Language Support    13
# dtype: int64

# %%
none_list = df[df['Family'].isna()]['Code'].tolist()
print(len(none_list), none_list)
# Out:
# 13 ['sqi', 'ara', 'kok', 'kur', 'lav', 'orm', 'pus', 'rom', 'srd', 'swa', 'tmh', 'yid', 'zza']

# %%
mapping = {
    'sqi': {'Family': 'Indo-European', 'Speaker': '1M to 1B', 'Vitality': 'Stable', 'Country': 'Albania', 'Digital Language Support': 'Emerging'},
    'ara': {'Family': 'Afro-Asiatic', 'Speaker': 'More than 1B', 'Vitality': 'Institutional', 'Country': 'Egypt', 'Digital Language Support': 'Thriving'},
    'kok': {'Family': 'Indo-European', 'Speaker': '1M to 1B', 'Vitality': 'Endangered', 'Country': 'India', 'Digital Language Support': 'Emerging'},
    'kur': {'Family': 'Indo-European', 'Speaker': '1M to 1B', 'Vitality': 'Endangered', 'Country': 'Turkey', 'Digital Language Support': 'Still'},
    'lav': {'Family': 'Indo-European', 'Speaker': '1M to 1B', 'Vitality': 'Stable', 'Country': 'Latvia', 'Digital Language Support': 'Ascending'},
    'orm': {'Family': 'Afro-Asiatic', 'Speaker': '1M to 1B', 'Vitality': 'Stable', 'Country': 'Ethiopia', 'Digital Language Support': 'Emerging'},
    'pus': {'Family': 'Indo-European', 'Speaker': '1M to 1B', 'Vitality': 'Stable', 'Country': 'Afghanistan', 'Digital Language Support': 'Emerging'},
    'rom': {'Family': 'Indo-European', 'Speaker': '10K to 1M', 'Vitality': 'Endangered', 'Country': 'Romania', 'Digital Language Support': 'Still'},
    'srd': {'Family': 'Indo-European', 'Speaker': '10K to 1M', 'Vitality': 'Endangered', 'Country': 'Italy', 'Digital Language Support': 'Still'},
    'swa': {'Family': 'Niger-Congo', 'Speaker': '1M to 1B', 'Vitality': 'Institutional', 'Country': 'Tanzania', 'Digital Language Support': 'Vital'},
    'tmh': {'Family': 'Afro-Asiatic', 'Speaker': '10K to 1M', 'Vitality': 'Endangered', 'Country': 'Mali', 'Digital Language Support': 'Still'},
    'yid': {'Family': 'Indo-European', 'Speaker': '10K to 1M', 'Vitality': 'Endangered', 'Country': 'USA', 'Digital Language Support': 'Emerging'},
    'zza': {'Family': 'Indo-European', 'Speaker': '10K to 1M', 'Vitality': 'Endangered', 'Country': 'Turkey', 'Digital Language Support': 'Still'},
}

# %%
for code, values in mapping.items():
    for column, value in values.items():
        df.loc[df['Code'] == code, column] = value

df
# Out:
#    Code  Language         Family        Speaker       Vitality  \
# 0   aar      Afar   Afro-Asiatic       1M to 1B  Institutional
# 1   awn      Agaw   Afro-Asiatic      10K to 1M         Stable
# 2   amp  Alamblak          Sepik  Less than 10K     Endangered
# 3   sqi  Albanian  Indo-European       1M to 1B         Stable
# 4   amh   Amharic   Afro-Asiatic       1M to 1B  Institutional
# ..  ...       ...            ...            ...            ...
# 85  cym     Welsh  Indo-European      10K to 1M  Institutional
# 86  wro  Worrorra     Australian            NaN     Endangered
# 87  yid   Yiddish  Indo-European      10K to 1M     Endangered
# 88  zne     Zande    Niger-Congo       1M to 1B  Institutional
# 89  zza    Zazaki  Indo-European      10K to 1M     Endangered
#
#                              Country Digital Language Support
# 0                           Ethiopia                 Emerging
# 1                           Ethiopia                 Emerging
# 2                   Papua New Guinea                    Still
# 3                            Albania                 Emerging
# 4                           Ethiopia                    Vital
# ..                               ...                      ...
# 85                    United Kingdom                    Vital
# 86                         Australia                    Still
# 87                               USA                 Emerging
# 88  Democratic Republic of the Congo                    Still
# 89                            Turkey                    Still
#
# [90 rows x 7 columns]

# %%
rows_with_nan = df[df.isna().any(axis=1)]

# Get unique codes
unique_codes_with_nan = rows_with_nan['Code'].unique()

# Display result
df.loc[df['Code'].isin(unique_codes_with_nan)]
# Out:
#    Code   Language         Family Speaker       Vitality        Country  \
# 13  cop     Coptic   Afro-Asiatic     NaN     Endangered          Egypt
# 41  lld      Ladin  Indo-European     NaN     Endangered          Italy
# 42  lat      Latin  Indo-European     NaN     Endangered  Vatican State
# 80  zgh  Tamazight   Afro-Asiatic     NaN  Institutional        Morocco
# 86  wro   Worrorra     Australian     NaN     Endangered      Australia
#
#    Digital Language Support
# 13                 Emerging
# 41                 Emerging
# 42                Ascending
# 80                Ascending
# 86                    Still

# %%
print(df.groupby('Vitality').size())
print('-'*50)
print(df.groupby('Speaker').size())
print('-'*50)
print(df.groupby('Family').size())
print('-'*50)
print(df.groupby('Digital Language Support').size())
# Out:
# Vitality
# Endangered       22
# Institutional    55
# Stable           13
# dtype: int64
# --------------------------------------------------
# Speaker
# 10K to 1M        21
# 1M to 1B         58
# Less than 10K     5
# More than 1B      1
# dtype: int64
# --------------------------------------------------
# Family
# Afro-Asiatic         13
# Australian            2
# Dravidian             1
# Indo-European        65
# Language isolate      1
# Matacoan              1
# Nakh-Daghestanian     1
# Niger-Congo           5
# Sepik                 1
# dtype: int64
# --------------------------------------------------
# Digital Language Support
# Ascending    23
# Emerging     14
# Still        11
# Thriving     27
# Vital        15
# dtype: int64

# %% [markdown]
# ### Digital Language Support
# **Still** — this language shows no signs of digital support \
# **Emerging** — the language has some content in digital form and/or encoding tools \
# **Ascending** — the language has some spell checking or localized tools or machine translation as well \
# **Vital** — the language is supported by multiple tools in all of the above categories and as well as some speech processing \
# **Thriving** — the language has all of the above plus virtual assistants
#
# ### Vitality
# **Institutional** — The language has been developed to the point that it is used and sustained by institutions beyond the home and community. \
# **Stable** — The language is not being sustained by formal institutions, but it is still the norm in the home and community that all children learn and use the language. \
# **Endangered** — It is no longer the norm that children learn and use this language. \
# **Extinct** - The language is no longer used and no one retains a sense of ethnic identity associated with the language.

# %% [markdown]
# ### Exclude languages with NaN users (language has no users) even if there is digital language support

# %%
df = df.dropna(subset=['Speaker'])
df
# Out:
#    Code  Language         Family        Speaker       Vitality  \
# 0   aar      Afar   Afro-Asiatic       1M to 1B  Institutional
# 1   awn      Agaw   Afro-Asiatic      10K to 1M         Stable
# 2   amp  Alamblak          Sepik  Less than 10K     Endangered
# 3   sqi  Albanian  Indo-European       1M to 1B         Stable
# 4   amh   Amharic   Afro-Asiatic       1M to 1B  Institutional
# ..  ...       ...            ...            ...            ...
# 84  vec  Venetian  Indo-European       1M to 1B         Stable
# 85  cym     Welsh  Indo-European      10K to 1M  Institutional
# 87  yid   Yiddish  Indo-European      10K to 1M     Endangered
# 88  zne     Zande    Niger-Congo       1M to 1B  Institutional
# 89  zza    Zazaki  Indo-European      10K to 1M     Endangered
#
#                              Country Digital Language Support
# 0                           Ethiopia                 Emerging
# 1                           Ethiopia                 Emerging
# 2                   Papua New Guinea                    Still
# 3                            Albania                 Emerging
# 4                           Ethiopia                    Vital
# ..                               ...                      ...
# 84                             Italy                Ascending
# 85                    United Kingdom                    Vital
# 87                               USA                 Emerging
# 88  Democratic Republic of the Congo                    Still
# 89                            Turkey                    Still
#
# [85 rows x 7 columns]

# %%
print(df.groupby('Vitality').size())
print('-'*50)
print(df.groupby('Speaker').size())
print('-'*50)
print(df.groupby('Family').size())
print('-'*50)
print(df.groupby('Digital Language Support').size())
# Out:
# Vitality
# Endangered       18
# Institutional    54
# Stable           13
# dtype: int64
# --------------------------------------------------
# Speaker
# 10K to 1M        21
# 1M to 1B         58
# Less than 10K     5
# More than 1B      1
# dtype: int64
# --------------------------------------------------
# Family
# Afro-Asiatic         11
# Australian            1
# Dravidian             1
# Indo-European        63
# Language isolate      1
# Matacoan              1
# Nakh-Daghestanian     1
# Niger-Congo           5
# Sepik                 1
# dtype: int64
# --------------------------------------------------
# Digital Language Support
# Ascending    21
# Emerging     12
# Still        10
# Thriving     27
# Vital        15
# dtype: int64

# %% [markdown]
# ### Exclude languages that show no signs of digital support

# %%
df = df[df['Digital Language Support'] != 'Still']
df
# Out:
#    Code   Language         Family       Speaker       Vitality  \
# 0   aar       Afar   Afro-Asiatic      1M to 1B  Institutional
# 1   awn       Agaw   Afro-Asiatic     10K to 1M         Stable
# 3   sqi   Albanian  Indo-European      1M to 1B         Stable
# 4   amh    Amharic   Afro-Asiatic      1M to 1B  Institutional
# 5   ara     Arabic   Afro-Asiatic  More than 1B  Institutional
# ..  ...        ...            ...           ...            ...
# 82  ukr  Ukrainian  Indo-European      1M to 1B  Institutional
# 83  urd       Urdu  Indo-European      1M to 1B  Institutional
# 84  vec   Venetian  Indo-European      1M to 1B         Stable
# 85  cym      Welsh  Indo-European     10K to 1M  Institutional
# 87  yid    Yiddish  Indo-European     10K to 1M     Endangered
#
#            Country Digital Language Support
# 0         Ethiopia                 Emerging
# 1         Ethiopia                 Emerging
# 3          Albania                 Emerging
# 4         Ethiopia                    Vital
# 5            Egypt                 Thriving
# ..             ...                      ...
# 82         Ukraine                 Thriving
# 83        Pakistan                    Vital
# 84           Italy                Ascending
# 85  United Kingdom                    Vital
# 87             USA                 Emerging
#
# [75 rows x 7 columns]

# %%
df.to_csv('output_data/dataset_v1.csv', index=False)

# %%
print(df.groupby('Vitality').size ())
print('-'*50) 
print(df.groupby('Speaker').size())
print('-'*50)
# print(df.groupby('Family').size())
# print('-'*50)
print(df.groupby('Digital Language Support').size())
# Out:
# Vitality
# Endangered       11
# Institutional    53
# Stable           11
# dtype: int64
# --------------------------------------------------
# Speaker
# 10K to 1M        16
# 1M to 1B         56
# Less than 10K     2
# More than 1B      1
# dtype: int64
# --------------------------------------------------
# Digital Language Support
# Ascending    21
# Emerging     12
# Thriving     27
# Vital        15
# dtype: int64

# %% [markdown]
# ### Digital Language Support
# **Still** — this language shows no signs of digital support \
# **Emerging** — the language has some content in digital form and/or encoding tools \
# **Ascending** — the language has some spell checking or localized tools or machine translation as well \
# **Vital** — the language is supported by multiple tools in all of the above categories and as well as some speech processing \
# **Thriving** — the language has all of the above plus virtual assistants
#
# ### Vitality
# **Institutional** — The language has been developed to the point that it is used and sustained by institutions beyond the home and community. \
# **Stable** — The language is not being sustained by formal institutions, but it is still the norm in the home and community that all children learn and use the language. \
# **Endangered** — It is no longer the norm that children learn and use this language. \
# **Extinct** - The language is no longer used and no one retains a sense of ethnic identity associated with the language.

# %%
df[df.Speaker == 'Less than 10K']
# Out:
#    Code Language         Family        Speaker    Vitality         Country  \
# 14  cor  Cornish  Indo-European  Less than 10K  Endangered  United Kingdom
# 49  glv     Manx  Indo-European  Less than 10K  Endangered     Isle of Man
#
#    Digital Language Support
# 14                Ascending
# 49                Ascending

# %%
df[df['Digital Language Support'] == 'Emerging']
# Out:
#    Code  Language             Family    Speaker       Vitality  \
# 0   aar      Afar       Afro-Asiatic   1M to 1B  Institutional
# 1   awn      Agaw       Afro-Asiatic  10K to 1M         Stable
# 3   sqi  Albanian      Indo-European   1M to 1B         Stable
# 7   bej      Beja       Afro-Asiatic   1M to 1B  Institutional
# 12  che   Chechen  Nakh-Daghestanian   1M to 1B         Stable
# 39  kok   Konkani      Indo-European   1M to 1B     Endangered
# 55  orm     Oromo       Afro-Asiatic   1M to 1B         Stable
# 56  pus    Pashto      Indo-European   1M to 1B         Stable
# 63  run     Rundi        Niger-Congo   1M to 1B  Institutional
# 65  rue     Rusyn      Indo-European  10K to 1M         Stable
# 66  ssy      Saho       Afro-Asiatic  10K to 1M  Institutional
# 87  yid   Yiddish      Indo-European  10K to 1M     Endangered
#
#                Country Digital Language Support
# 0             Ethiopia                 Emerging
# 1             Ethiopia                 Emerging
# 3              Albania                 Emerging
# 7                Sudan                 Emerging
# 12  Russian Federation                 Emerging
# 39               India                 Emerging
# 55            Ethiopia                 Emerging
# 56         Afghanistan                 Emerging
# 63             Burundi                 Emerging
# 65             Ukraine                 Emerging
# 66             Eritrea                 Emerging
# 87                 USA                 Emerging
