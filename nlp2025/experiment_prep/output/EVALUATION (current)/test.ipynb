# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Example labels
predicted_labels = [True, False, True, True, False, False]
true_labels = [True, True, True, False, False, False]

# Calculate metrics
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

# Display the results
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Precision: 0.67
# Recall: 0.67
# F1-Score: 0.67

# %%
data = pd.read_csv('accuracy/claude-3-opus/deu.csv')

# Function to clean double spaces and leave dots intact
df_cleaned = data.applymap(lambda x: ' '.join(str(x).split()) if isinstance(x, str) else x)

# Display the cleaned DataFrame
df_cleaned['deu_f']
# Out:
# 0            Ich bin Afghanin.
# 1         Ich bin Angolanerin.
# 2           Ich bin Albanerin.
# 3        Ich bin Andorranerin.
# 4                          NaN
#                 ...
# 188        Ich bin Samoanerin.
# 189         Ich bin Jemenitin.
# 190    Ich bin Südafrikanerin.
# 191         Ich bin Sambierin.
# 192       Ich bin Simbabwerin.
# Name: deu_f, Length: 193, dtype: object

# %%
test = 'Ich bin  Afghanin.'
test = test.strip()
test
# Out:
# 'Ich bin  Afghanin.'

# %%
import pandas as pd
import numpy as np
from typing import List, Dict
from collections import Counter

def analyze_translations(df: pd.DataFrame) -> Dict:
    """
    Analyze translation patterns and compute various metrics for the dataset.
    
    Parameters:
    df (pd.DataFrame): DataFrame with columns 'eng', 'deu_m', 'deu_f', 'deu_n', 'extracted'
    
    Returns:
    Dict: Dictionary containing various metrics and analysis results
    """
    metrics = {}
    
    # 1. Coverage Analysis
    total_entries = len(df)
    complete_entries = df[df['deu_m'].notna() & df['deu_f'].notna()].shape[0]
    metrics['coverage'] = {
        'total_entries': total_entries,
        'complete_entries': complete_entries,
        'coverage_percentage': (complete_entries / total_entries) * 100
    }
    
    # 2. Pattern Analysis
    def extract_patterns(row):
        if pd.isna(row['deu_m']) or pd.isna(row['deu_f']):
            return None
        
        m_ending = row['deu_m'].split('.')[-2].split()[-1]
        f_ending = row['deu_f'].split('.')[-2].split()[-1]
        return f"{m_ending}->{f_ending}"
    
    patterns = df.apply(extract_patterns, axis=1).dropna()
    pattern_counts = Counter(patterns)
    metrics['gender_patterns'] = dict(pattern_counts)
    
    # 3. Consistency Analysis
    def check_consistency(row):
        if pd.isna(row['extracted']):
            return False
        extracted = eval(row['extracted'])
        if not isinstance(extracted, list):
            return False
        
        expected = [x for x in [row['deu_m'], row['deu_f'], row['deu_n']] if pd.notna(x)]
        matches = sum(1 for e in extracted if any(e.strip() == exp.strip() for exp in expected))
        return matches == len(extracted)
    
    consistent_entries = df.apply(check_consistency, axis=1).sum()
    metrics['consistency'] = {
        'consistent_entries': consistent_entries,
        'consistency_percentage': (consistent_entries / total_entries) * 100
    }
    
    # 4. Gender Form Analysis
    metrics['gender_forms'] = {
        'masculine_present': df['deu_m'].notna().sum(),
        'feminine_present': df['deu_f'].notna().sum(),
        'neuter_present': df['deu_n'].notna().sum()
    }
    
    return metrics

def print_metrics(metrics: Dict):
    """
    Print the analysis metrics in a readable format.
    """
    print("=== Translation Analysis Results ===\n")
    
    print("1. Coverage Metrics:")
    print(f"Total entries: {metrics['coverage']['total_entries']}")
    print(f"Complete entries: {metrics['coverage']['complete_entries']}")
    print(f"Coverage percentage: {metrics['coverage']['coverage_percentage']:.2f}%\n")
    
    print("2. Most Common Gender Patterns:")
    sorted_patterns = sorted(metrics['gender_patterns'].items(), 
                           key=lambda x: x[1], reverse=True)
    for pattern, count in sorted_patterns[:5]:
        print(f"{pattern}: {count} occurrences")
    print()
    
    print("3. Consistency Metrics:")
    print(f"Consistent entries: {metrics['consistency']['consistent_entries']}")
    print(f"Consistency percentage: {metrics['consistency']['consistency_percentage']:.2f}%\n")
    
    print("4. Gender Form Distribution:")
    print(f"Masculine forms: {metrics['gender_forms']['masculine_present']}")
    print(f"Feminine forms: {metrics['gender_forms']['feminine_present']}")
    print(f"Neuter forms: {metrics['gender_forms']['neuter_present']}")

# %%
df = pd.read_csv('../ready_for_evaluation/gpt-4/deu.csv')
print_metrics(analyze_translations(df))
# Out:
# === Translation Analysis Results ===
#
# 1. Coverage Metrics:
# Total entries: 193
# Complete entries: 188
# Coverage percentage: 97.41%
#
# 2. Most Common Gender Patterns:
# Kongolese->Kongolesin: 2 occurrences
# Afghane->Afghanin: 1 occurrences
# Angolaner->Angolanerin: 1 occurrences
# Albaner->Albanerin: 1 occurrences
# Andorraner->Andorranerin: 1 occurrences
#
# 3. Consistency Metrics:
# Consistent entries: 136
# Consistency percentage: 70.47%
#
# 4. Gender Form Distribution:
# Masculine forms: 188
# Feminine forms: 188
# Neuter forms: 1

# %%
import pandas as pd

# Load the CSV file
file_path = '../ready_for_evaluation/gpt-4/deu.csv'
data = pd.read_csv(file_path)

# Function to determine if the prediction in 'extracted' matches any of the true values
def is_correct_prediction(row):
    # Collect true values from spa_m, spa_f, and spa_n
    true_values = {row['deu_m'], row['deu_f'], row['deu_n']}
    true_values = {val for val in true_values if pd.notna(val)}  # Remove NaN values
    
    # Collect predicted values from extracted
    predicted_values = eval(row['extracted']) if pd.notna(row['extracted']) else []
    print(f"True values: {true_values}")
    print(f"Predicted values: {predicted_values}\n\n")
    # Check if any predicted value matches the true values
    return any(pred in true_values for pred in predicted_values)

# Apply the function to calculate correctness for each row
data['is_correct'] = data.apply(is_correct_prediction, axis=1)

# Calculate accuracy
total_predictions = len(data)
correct_predictions = data['is_correct'].sum()
accuracy = correct_predictions / total_predictions

# Print results
print(f"Total Predictions: {total_predictions}")
print(f"Correct Predictions: {correct_predictions}")
print(f"Accuracy: {accuracy:.2%}")
# Out:
# True values: {'Ich bin Afghane.', 'Ich bin  Afghanin.'}
# Predicted values: ['Ich bin Afghane.']
#
#
# True values: {'Ich bin Angolaner.', 'Ich bin  Angolanerin.'}
# Predicted values: ['Ich bin Angolaner.']
#
#
# True values: {'Ich bin  Albanerin.', 'Ich bin Albaner.'}
# Predicted values: ['Ich bin Albaner.']
#
#
# True values: {'Ich bin  Andorranerin.', 'Ich bin Andorraner.'}
# Predicted values: ['Ich bin Andorraner.']
#
#
# True values: set()
# Predicted values: ['Ich bin Emirati.']
#
#
# True values: {'Ich bin Argentinier.', 'Ich bin  Argentinierin.'}
# Predicted values: ['Ich bin Argentinier.']
#
#
# True values: {'Ich bin  Armenierin.', 'Ich bin Armenier.'}
# Predicted values: ['Ich bin Armenier.']
#
#
# True values: {'Ich bin Antiguaner.', 'Ich bin  Antiguanerin.'}
# Predicted values: ['Ich bin Antiguaner.']
#
#
# True values: {'Ich bin  Australierin.', 'Ich bin Australier.'}
# Predicted values: ['Ich bin Australier.']
#
#
# True values: {'Ich bin  Österreicherin.', 'Ich bin Österreicher.'}
# Predicted values: ['Ich bin Österreicher.']
#
#
# True values: {'Ich bin Aserbaidschaner.', 'Ich bin  Aserbaidschanerin.'}
# Predicted values: ['Ich bin Aserbaidschaner.']
#
#
# True values: {'Ich bin Burundierin.', 'Ich bin Burundier.'}
# Predicted values: ['Ich bin Burundier.']
#
#
# True values: {'Ich bin Belgierin.', 'Ich bin Belgier.'}
# Predicted values: ['Ich bin Belgier.']
#
#
# True values: {'Ich bin  Beninerin.', 'Ich bin Beniner.'}
# Predicted values: ['Ich bin Beniner.']
#
#
# True values: {'Ich bin Burkiner.', 'Ich bin  Burkinerin.'}
# Predicted values: ['Ich bin Burkinabe.']
#
#
# True values: {'Ich bin  Bangladescherin.', 'Ich bin Bangladescher.'}
# Predicted values: ['Ich bin Bangladeschi.']
#
#
# True values: {'Ich bin  Bulgarin.', 'Ich bin Bulgare.'}
# Predicted values: ['Ich bin Bulgarin.']
#
#
# True values: {'Ich bin Bahrainer.', 'Ich bin  Bahrainerin.'}
# Predicted values: ['Ich bin Bahraini.']
#
#
# True values: {'Ich bin  Bahamaerin.', 'Ich bin Bahamaer.'}
# Predicted values: ['Ich bin Bahamaer.']
#
#
# True values: {'Ich bin  Bosnierin.', 'Ich bin Bosnier.'}
# Predicted values: ['Ich bin Bosnier.']
#
#
# True values: {'Ich bin Belarusse.', 'Ich bin  Belarussin.'}
# Predicted values: ['Ich bin Weißrusse.']
#
#
# True values: {'Ich bin  Belizerin.', 'Ich bin Belizer.'}
# Predicted values: ['Ich bin Belizeaner.']
#
#
# True values: {'Ich bin  Bolivianerin.', 'Ich bin Bolivianer.'}
# Predicted values: ['Ich bin Bolivianer.']
#
#
# True values: {'Ich bin  Brasilianerin.', 'Ich bin Brasilianer.'}
# Predicted values: ['Ich bin Brasilianer.']
#
#
# True values: {'Ich bin Barbadier.', 'Ich bin  Barbadierin.'}
# Predicted values: ['Ich bin Barbadier.']
#
#
# True values: {'Ich bin Bruneier.', 'Ich bin  Bruneierin.'}
# Predicted values: ['Ich bin Bruneier.']
#
#
# True values: {'Ich bin  Bhutanerin.', 'Ich bin Bhutaner.'}
# Predicted values: ['Ich bin Bhutaner.']
#
#
# True values: {'Ich bin Botsuaner.', 'Ich bin  Botsuanerin.'}
# Predicted values: ['Ich bin Motswana.']
#
#
# True values: {'Ich bin  Zentralafrikanerin.', 'Ich bin Zentralafrikaner.'}
# Predicted values: ['Ich bin Zentralafrikaner.']
#
#
# True values: {'Ich bin  Kanadierin.', 'Ich bin Kanadier.'}
# Predicted values: ['Ich bin Kanadier.']
#
#
# True values: {'Ich bin  Schweizerin.', 'Ich bin Schweizer.'}
# Predicted values: ['Ich bin Schweizer.']
#
#
# True values: {'Ich bin  Chilenin.', 'Ich bin Chilene.'}
# Predicted values: ['Ich bin Chilene.']
#
#
# True values: {'Ich bin Chinese.', 'Ich bin  Chinesin.'}
# Predicted values: ['Ich bin Chinesisch.']
#
#
# True values: {'Ich bin Ivorer.', 'Ich bin Ivorerin.'}
# Predicted values: ['Ich bin Ivorer.']
#
#
# True values: {'Ich bin Kameruner.', 'Ich bin  Kamerunerin.'}
# Predicted values: ['Ich bin Kameruner.']
#
#
# True values: {'Ich bin Kongolese.', 'Ich bin Kongolesin.'}
# Predicted values: ['Ich bin Kongolese.']
#
#
# True values: {'Ich bin Kongolese.', 'Ich bin Kongolesin.'}
# Predicted values: ['Ich bin Kongolesisch.']
#
#
# True values: {'Ich bin Kolumbianer.', 'Ich bin  Kolumbianerin.'}
# Predicted values: ['Ich bin Kolumbianer.']
#
#
# True values: {'Ich bin Komorer.', 'Ich bin  Komorerin.'}
# Predicted values: ['Ich bin Komorer.']
#
#
# True values: set()
# Predicted values: ['Ich bin Kapverdier.']
#
#
# True values: {'Ich bin Costa Ricaner.', 'Ich bin  Costa Ricanerin.'}
# Predicted values: ['Ich bin Costa Ricaner.']
#
#
# True values: {'Ich bin Kubaner.', 'Ich bin  Kubanerin.'}
# Predicted values: ['Ich bin Kubaner.']
#
#
# True values: {'Ich bin  Zyprerin.', 'Ich bin Zyprer.'}
# Predicted values: ['Ich bin Zypriot.']
#
#
# True values: {'Ich bin Tschechin.', 'Ich bin Tscheche.'}
# Predicted values: ['Ich bin Tscheche.']
#
#
# True values: {'Ich bin Deutsche.', 'Ich bin  Deutsche.'}
# Predicted values: ['Ich bin Deutsch.']
#
#
# True values: {'Ich bin Dschibutier.', 'Ich bin  Dschibutierin.'}
# Predicted values: ['Ich bin Dschibuti.']
#
#
# True values: {'Ich bin Dominicaner.', 'Ich bin Dominicanerin.'}
# Predicted values: ['Ich bin Dominikaner.']
#
#
# True values: {'Ich bin  Dänin.', 'Ich bin Däne.'}
# Predicted values: ['Ich bin Däne.']
#
#
# True values: {'Ich bin  Dominikanerin.', 'Ich bin Dominikaner.'}
# Predicted values: ['Ich bin Dominikaner.']
#
#
# True values: {'Ich bin Algerier.', 'Ich bin  Algerierin.'}
# Predicted values: ['Ich bin Algerier.']
#
#
# True values: {'Ich bin  Ecuadorianerin.', 'Ich bin Ecuadorianer.'}
# Predicted values: ['Ich bin Ecuadorianer.']
#
#
# True values: {'Ich bin Ägypter.', 'Ich bin  Ägypterin.'}
# Predicted values: ['Ich bin Ägypter.']
#
#
# True values: {'Ich bin Eritreer.', 'Ich bin  Eritreerin.'}
# Predicted values: ['Ich bin Eritreer.']
#
#
# True values: {'Ich bin  Spanierin.', 'Ich bin Spanier.'}
# Predicted values: ['Ich bin Spanier.']
#
#
# True values: {'Ich bin  Estin.', 'Ich bin Este.'}
# Predicted values: ['Ich bin Estländer.']
#
#
# True values: {'Ich bin Äthiopier.', 'Ich bin  Äthiopierin.'}
# Predicted values: ['Ich bin Äthiopier.']
#
#
# True values: {'Ich bin  Finnin.', 'Ich bin Finne.'}
# Predicted values: ['Ich bin Finne.']
#
#
# True values: {'Ich bin Fidschianer.', 'Ich bin  Fidschianerin.'}
# Predicted values: ['Ich bin Fidschianer.']
#
#
# True values: {'Ich bin  Französin.', 'Ich bin Franzose.'}
# Predicted values: ['Ich bin Franzose.', 'Ich bin Französin.']
#
#
# True values: {'Ich bin  Mikronesierin.', 'Ich bin Mikronesier.'}
# Predicted values: ['Ich bin Mikronesier.']
#
#
# True values: {'Ich bin  Gabunerin.', 'Ich bin Gabuner.'}
# Predicted values: ['Ich bin Gabuner.']
#
#
# True values: {'Ich bin Brite.', 'Ich bin  Britin.'}
# Predicted values: ['Ich bin Brite.']
#
#
# True values: {'Ich bin  Georgierin.', 'Ich bin Georgier.'}
# Predicted values: ['Ich bin Georgier.']
#
#
# True values: {'Ich bin Ghanaer.', 'Ich bin  Ghanaerin.'}
# Predicted values: ['Ich bin Ghanaer.']
#
#
# True values: {'Ich bin Guineer.', 'Ich bin  Guineerin.'}
# Predicted values: ['Ich bin Guineer.']
#
#
# True values: {'Ich bin Gambierin.', 'Ich bin Gambier.'}
# Predicted values: ['Ich bin Gambier.']
#
#
# True values: {'Ich bin Guinea-Bissauer.', 'Ich bin Guinea-Bissauerin.'}
# Predicted values: ['Ich bin aus Guinea-Bissau.']
#
#
# True values: {'Ich bin Äquatorialguineer.', 'Ich bin  Äquatorialguineerin.'}
# Predicted values: ['Ich bin aus Äquatorialguinea.']
#
#
# True values: {'Ich bin  Griechin.', 'Ich bin Grieche.'}
# Predicted values: ['Ich bin Grieche.']
#
#
# True values: {'Ich bin  Grenaderin.', 'Ich bin Grenader.'}
# Predicted values: ['Ich bin Grenadier.']
#
#
# True values: {'Ich bin  Guatemaltekin.', 'Ich bin Guatemalteke.'}
# Predicted values: ['Ich bin Guatemalteke.']
#
#
# True values: {'Ich bin  Guyanerin.', 'Ich bin Guyaner.'}
# Predicted values: ['Ich bin Guyaner.']
#
#
# True values: {'Ich bin Honduraner.', 'Ich bin  Honduranerin.'}
# Predicted values: ['Ich bin Honduraner.']
#
#
# True values: {'Ich bin Kroate.', 'Ich bin  Kroatin.'}
# Predicted values: ['Ich bin Kroate.']
#
#
# True values: {'Ich bin  Haitinaerin.', 'Ich bin Haitianer.'}
# Predicted values: ['Ich bin Haitianer.']
#
#
# True values: {'Ich bin Ungar.', 'Ich bin  Ungarin.'}
# Predicted values: ['Ich bin Ungar.']
#
#
# True values: {'Ich bin Indonesier.', 'Ich bin  Indonesierin.'}
# Predicted values: ['Ich bin Indonesier.']
#
#
# True values: {'Ich bin Inder.', 'Ich bin  Inderin.'}
# Predicted values: ['Ich bin Inder.']
#
#
# True values: {'Ich bin  Irin.', 'Ich bin Ire.'}
# Predicted values: ['Ich bin Ire.']
#
#
# True values: {'Ich bin Iraner.', 'Ich bin  Iranerin.'}
# Predicted values: ['Ich bin Iraner.']
#
#
# True values: {'Ich bin  Irakerin.', 'Ich bin Iraker.'}
# Predicted values: ['Ich bin Iraker.']
#
#
# True values: {'Ich bin  Isländerin.', 'Ich bin Isländer.'}
# Predicted values: ['Ich bin Isländer.']
#
#
# True values: {'Ich bin Israelin.', 'Ich bin Israeli.'}
# Predicted values: ['Ich bin Israeli.']
#
#
# True values: {'Ich bin  Italienerin.', 'Ich bin Italiener.'}
# Predicted values: ['Ich bin Italiener.']
#
#
# True values: {'Ich bin  Jamaikanerin.', 'Ich bin Jamaikaner.'}
# Predicted values: ['Ich bin Jamaikaner.']
#
#
# True values: {'Ich bin Jordanier.', 'Ich bin  Jordanierin.'}
# Predicted values: ['Ich bin Jordanier.']
#
#
# True values: {'Ich bin  Japanerin.', 'Ich bin Japaner.'}
# Predicted values: ['Ich bin Japaner.']
#
#
# True values: {'Ich bin Kasache.', 'Ich bin  Kasachin.'}
# Predicted values: ['Ich bin Kasache.']
#
#
# True values: {'Ich bin Kenianer.', 'Ich bin  Kenianerin.'}
# Predicted values: ['Ich bin Kenianer.']
#
#
# True values: {'Ich bin Kirgise.', 'Ich bin  Kirgisin.'}
# Predicted values: ['Ich bin Kirgise.']
#
#
# True values: {'Ich bin Kambodschaner.', 'Ich bin  Kambodschanerin.'}
# Predicted values: ['Ich bin Kambodschaner.']
#
#
# True values: {'Ich bin Kiribatier.', 'Ich bin  Kiribatierin.'}
# Predicted values: ['Ich bin I-Kiribati.']
#
#
# True values: set()
# Predicted values: ['Ich bin Kittitianer oder Nevisianer.']
#
#
# True values: {'Ich bin  Südkoreanerin.', 'Ich bin Südkoreaner.'}
# Predicted values: ['Ich bin Südkoreaner.']
#
#
# True values: {'Ich bin Kuwaiter.', 'Ich bin  Kuwaiterin.'}
# Predicted values: ['Ich bin Kuwaiti.']
#
#
# True values: {'Ich bin  Laotin.', 'Ich bin Laote.'}
# Predicted values: ['Ich bin Laote.']
#
#
# True values: {'Ich bin Libanese.', 'Ich bin  Libanesin.'}
# Predicted values: ['Ich bin Libanese.']
#
#
# True values: {'Ich bin Liberianer.', 'Ich bin  Liberianerin.'}
# Predicted values: ['Ich bin Liberianer.']
#
#
# True values: {'Ich bin  Libyerin.', 'Ich bin Libyer.'}
# Predicted values: ['Ich bin Libyer.']
#
#
# True values: {'Ich bin Lucianer.', 'Ich bin Lucianerin.'}
# Predicted values: ['Ich bin aus St. Lucia.']
#
#
# True values: {'Ich bin  Liechtensteinerin.', 'Ich bin Liechtensteiner.'}
# Predicted values: ['Ich bin Liechtensteiner.']
#
#
# True values: {'Ich bin  Sri Lankerin.', 'Ich bin Sri Lanker.'}
# Predicted values: ['Ich bin Sri Lankaner.']
#
#
# True values: {'Ich bin  Lesotherin.', 'Ich bin Lesother.'}
# Predicted values: ['Ich bin Mosotho.']
#
#
# True values: {'Ich bin Litauer.', 'Ich bin  Litauerin.'}
# Predicted values: ['Ich bin Litauer.']
#
#
# True values: {'Ich bin Luxemburger.', 'Ich bin  Luxemburgerin.'}
# Predicted values: ['Ich bin Luxemburger.']
#
#
# True values: {'Ich bin Lette.', 'Ich bin  Lettin.'}
# Predicted values: ['Ich bin Lettisch.']
#
#
# True values: {'Ich bin  Marokkanerin.', 'Ich bin Marokkaner.'}
# Predicted values: ['Ich bin Marokkaner.']
#
#
# True values: {'Ich bin  Monegassin.', 'Ich bin Monegasse.'}
# Predicted values: ['Ich bin Monegasse.']
#
#
# True values: {'Ich bin  Moldauerin.', 'Ich bin Moldauer.'}
# Predicted values: ['Ich bin Moldauer.']
#
#
# True values: {'Ich bin Madagasse.', 'Ich bin  Madagassin.'}
# Predicted values: ['Ich bin Madagasse.']
#
#
# True values: {'Ich bin  Malediverin.', 'Ich bin Malediver.'}
# Predicted values: ['Ich bin Malediver.']
#
#
# True values: {'Ich bin  Mexikanerin.', 'Ich bin Mexikaner.'}
# Predicted values: ['Ich bin Mexikaner.']
#
#
# True values: {'Ich bin Marshaller.', 'Ich bin  Marshallerin.'}
# Predicted values: ['Ich bin Marshallese.']
#
#
# True values: {'Ich bin  Mazedonierin.', 'Ich bin Mazedonier.'}
# Predicted values: ['Ich bin Mazedonier.']
#
#
# True values: {'Ich bin Malier.', 'Ich bin  Malierin.'}
# Predicted values: ['Ich bin Malier.']
#
#
# True values: {'Ich bin  Malteserin.', 'Ich bin Malteser.'}
# Predicted values: ['Ich bin Malteser.']
#
#
# True values: {'Ich bin  Myanmarin.', 'Ich bin Myanmare.'}
# Predicted values: ['Ich bin Burmese.']
#
#
# True values: {'Ich bin  Montenegrinerin.', 'Ich bin Montenegriner.'}
# Predicted values: ['Ich bin Montenegriner.']
#
#
# True values: {'Ich bin  Mongolin.', 'Ich bin Mongole.'}
# Predicted values: ['Ich bin Mongole.']
#
#
# True values: {'Ich bin  Mosambikanerin.', 'Ich bin Mosambikaner.'}
# Predicted values: ['Ich bin Mosambikaner.']
#
#
# True values: {'Ich bin Mauretanier.', 'Ich bin  Mauretanierin.'}
# Predicted values: ['Ich bin Mauretanier.']
#
#
# True values: {'Ich bin  Mauritierin.', 'Ich bin Mauritier.'}
# Predicted values: ['Ich bin Mauritianer.']
#
#
# True values: {'Ich bin  Malawierin.', 'Ich bin Malawier.'}
# Predicted values: ['Ich bin Malawier.']
#
#
# True values: {'Ich bin Malaysier.', 'Ich bin  Malaysierin.'}
# Predicted values: ['Ich bin Malaysier.']
#
#
# True values: {'Ich bin Namibier.', 'Ich bin  Namibierin.'}
# Predicted values: ['Ich bin Namibier.']
#
#
# True values: {'Ich bin  Nigrerin.', 'Ich bin Nigrer.'}
# Predicted values: ['Ich bin aus Niger.']
#
#
# True values: {'Ich bin  Nigerianerin.', 'Ich bin Nigerianer.'}
# Predicted values: ['Ich bin Nigerianer.']
#
#
# True values: {'Ich bin  Nicaraguanerin.', 'Ich bin Nicaraguaner.'}
# Predicted values: ['Ich bin Nicaraguaner.']
#
#
# True values: {'Ich bin  Niederländerin.', 'Ich bin Niederländer.'}
# Predicted values: ['Ich bin Niederländer.']
#
#
# True values: {'Ich bin  Norwegerin.', 'Ich bin Norweger.'}
# Predicted values: ['Ich bin Norweger.']
#
#
# True values: {'Ich bin Nepalese.', 'Ich bin  Nepalesin.'}
# Predicted values: ['Ich bin Nepalese.']
#
#
# True values: {'Ich bin Nauruer.', 'Ich bin  Nauruerin.'}
# Predicted values: ['Ich bin Nauruaner.']
#
#
# True values: {'Ich bin Neuseeländer.', 'Ich bin  Neuseeländerin.'}
# Predicted values: ['Ich bin Neuseeländer.']
#
#
# True values: {'Ich bin Omaner.', 'Ich bin  Omanerin.'}
# Predicted values: ['Ich bin Omaner.']
#
#
# True values: {'Ich bin  Pakistanerin.', 'Ich bin Pakistaner.'}
# Predicted values: ['Ich bin Pakistani.']
#
#
# True values: {'Ich bin Panamaer.', 'Ich bin  Panamaerin.'}
# Predicted values: ['Ich bin Panamaisch.']
#
#
# True values: {'Ich bin Peruaner.', 'Ich bin  Peruanerin.'}
# Predicted values: ['Ich bin Peruaner.']
#
#
# True values: {'Ich bin  Philippinerin.', 'Ich bin Philippiner.'}
# Predicted values: ['Ich bin Filipino.']
#
#
# True values: {'Ich bin Palauer.', 'Ich bin  Palauerin.'}
# Predicted values: ['Ich bin Palauer.']
#
#
# True values: {'Ich bin  PapuaNeuguineerin.', 'Ich bin PapuaNeuguineer.'}
# Predicted values: ['Ich bin Papua-Neuguineer.']
#
#
# True values: {'Ich bin  Polin.', 'Ich bin Pole.'}
# Predicted values: ['Ich bin Pole.']
#
#
# True values: {'Ich bin Nordkoreaner.', 'Ich bin  Nordkoreanerin.'}
# Predicted values: ['Ich bin Nordkoreaner.']
#
#
# True values: {'Ich bin Portugiese.', 'Ich bin  Portugiesin.'}
# Predicted values: ['Ich bin Portugiese.']
#
#
# True values: {'Ich bin Paraguayer.', 'Ich bin  Paraguayerin.'}
# Predicted values: ['Ich bin Paraguayer.']
#
#
# True values: {'Ich bin  Katarerin.', 'Ich bin Katarer.'}
# Predicted values: ['Ich bin Katarer.']
#
#
# True values: {'Ich bin Rumäne.', 'Ich bin  Rumänin.'}
# Predicted values: ['Ich bin Rumäne.']
#
#
# True values: {'Ich bin Russe.', 'Ich bin  Russin.'}
# Predicted values: ['Ich bin Russe.']
#
#
# True values: {'Ich bin  Ruanderin.', 'Ich bin Ruander.'}
# Predicted values: ['Ich bin Ruander.']
#
#
# True values: {'Ich bin  SaudiAraberin.', 'Ich bin SaudiAraber.'}
# Predicted values: ['Ich bin Saudi-Araber.']
#
#
# True values: {'Ich bin  Sudanerin.', 'Ich bin Sudaner.'}
# Predicted values: ['Ich bin Sudanese.']
#
#
# True values: {'Ich bin Senegalese.', 'Ich bin  Senegalesin.'}
# Predicted values: ['Ich bin Senegalese.']
#
#
# True values: {'Ich bin Singapurer.', 'Ich bin  Singapurerin.'}
# Predicted values: ['Ich bin Singapurer.']
#
#
# True values: {'Ich bin  Salomonerin.', 'Ich bin Salomoner.'}
# Predicted values: ['Ich bin Salomoneninsulaner.']
#
#
# True values: {'Ich bin SierraLeoner.', 'Ich bin  SierraLeonerin.'}
# Predicted values: ['Ich bin Sierra Leoner.']
#
#
# True values: {'Ich bin Salvadorianer.', 'Ich bin  Salvadorianerin.'}
# Predicted values: ['Ich bin Salvadorianer.']
#
#
# True values: {'Ich bin SanMarinese.', 'Ich bin  SanMarinesin.'}
# Predicted values: ['Ich bin San-Marinese.']
#
#
# True values: {'Ich bin Somalier.', 'Ich bin  Somalierin.'}
# Predicted values: ['Ich bin Somali.']
#
#
# True values: {'Ich bin Serbe.', 'Ich bin  Serbin.'}
# Predicted values: ['Ich bin Serbe.']
#
#
# True values: {'Ich bin Südsudaner.', 'Ich bin  Südsudanerin.'}
# Predicted values: ['Ich bin Südsudanese.']
#
#
# True values: {'Ich bin São Toméerin.', 'Ich bin São Toméer.'}
# Predicted values: ['Ich bin aus São Tomé.']
#
#
# True values: {'Ich bin Surinamer.', 'Ich bin Surinamerin.'}
# Predicted values: ['Ich bin Surinamer.']
#
#
# True values: {'Ich bin Slowake.', 'Ich bin  Slowakin.'}
# Predicted values: ['Ich bin Slowake.']
#
#
# True values: {'Ich bin  Slowenin.', 'Ich bin Slowene.'}
# Predicted values: ['Ich bin Slowene.']
#
#
# True values: {'Ich bin Schwede.', 'Ich bin  Schwedin.'}
# Predicted values: ['Ich bin Schwedisch.']
#
#
# True values: {'Ich bin Swasi.'}
# Predicted values: ['Ich bin Swazi.']
#
#
# True values: {'Ich bin  Seychellerin.', 'Ich bin Seycheller.'}
# Predicted values: ['Ich bin Seychellois.']
#
#
# True values: {'Ich bin Syrer.', 'Ich bin  Syrerin.'}
# Predicted values: ['Ich bin Syrer.']
#
#
# True values: {'Ich bin Tschader.', 'Ich bin  Tschaderin.'}
# Predicted values: ['Ich bin Tschader.']
#
#
# True values: {'Ich bin Togoer.', 'Ich bin  Togoerin.'}
# Predicted values: ['Ich bin Togolese.']
#
#
# True values: {'Ich bin Thailänder.', 'Ich bin  Thailänderin.'}
# Predicted values: ['Ich bin Thailänder.']
#
#
# True values: {'Ich bin  Tadschikin.', 'Ich bin Tadschike.'}
# Predicted values: ['Ich bin Tadschik.']
#
#
# True values: {'Ich bin Turkmene.', 'Ich bin  Turkmenin.'}
# Predicted values: ['Ich bin Turkmenin.']
#
#
# True values: {'Ich bin Timorer.', 'Ich bin Timorerin.'}
# Predicted values: ['Ich bin Osttimorese.']
#
#
# True values: {'Ich bin  Tongaerin.', 'Ich bin Tongaer.'}
# Predicted values: ['Ich bin Tonganer.']
#
#
# True values: set()
# Predicted values: ['Ich bin Trinidader.']
#
#
# True values: {'Ich bin Tunesier.', 'Ich bin  Tunesierin.'}
# Predicted values: ['Ich bin Tunesier.']
#
#
# True values: {'Ich bin Türke.', 'Ich bin  Türkin.'}
# Predicted values: ['Ich bin Türke.']
#
#
# True values: {'Ich bin Tuvaluer.', 'Ich bin  Tuvaluerin.'}
# Predicted values: ['Ich bin Tuvaluaner.']
#
#
# True values: {'Ich bin Tansanier.', 'Ich bin  Tansanierin.'}
# Predicted values: ['Ich bin Tansanier.']
#
#
# True values: {'Ich bin  Uganderin.', 'Ich bin Ugander.'}
# Predicted values: ['Ich bin Ugander.']
#
#
# True values: {'Ich bin  Ukrainerin.', 'Ich bin Ukrainer.'}
# Predicted values: ['Ich bin Ukrainer.']
#
#
# True values: {'Ich bin Uruguayer.', 'Ich bin  Uruguayerin.'}
# Predicted values: ['Ich bin Uruguayer.']
#
#
# True values: {'Ich bin Amerikanerin.', 'Ich bin Amerikaner.'}
# Predicted values: ['Ich bin Amerikaner.']
#
#
# True values: {'Ich bin  Usbekin.', 'Ich bin Usbeke.'}
# Predicted values: ['Ich bin Usbeke.']
#
#
# True values: {'Ich bin Vincenter.', 'Ich bin Vincenterin.'}
# Predicted values: ['Ich bin Vincentianer.']
#
#
# True values: {'Ich bin Venezolaner.', 'Ich bin  Venezolanerin.'}
# Predicted values: ['Ich bin Venezolaner.']
#
#
# True values: {'Ich bin Vietnamese.', 'Ich bin  Vietnamesin.'}
# Predicted values: ['Ich bin Vietnamesisch.']
#
#
# True values: {'Ich bin Vanuatuer.', 'Ich bin  Vanuatuerin.'}
# Predicted values: ['Ich bin Ni-Vanuatu.']
#
#
# True values: {'Ich bin  Samoanerin.', 'Ich bin Samoaner.'}
# Predicted values: ['Ich bin Samoaner.']
#
#
# True values: {'Ich bin  Jemenitin.', 'Ich bin Jemenit.'}
# Predicted values: ['Ich bin Jemenit.']
#
#
# True values: {'Ich bin Südafrikaner.', 'Ich bin  Südafrikanerin.'}
# Predicted values: ['Ich bin Südafrikaner.']
#
#
# True values: {'Ich bin  Sambierin.', 'Ich bin Sambier.'}
# Predicted values: ['Ich bin Sambier.']
#
#
# True values: {'Ich bin Simbabwer.', 'Ich bin  Simbabwerin.'}
# Predicted values: ['Ich bin Simbabwer.']
#
#
# Total Predictions: 193
# Correct Predictions: 137
# Accuracy: 70.98%
