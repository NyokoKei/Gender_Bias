# %%
import pandas as pd

# %%
df = pd.read_csv(f"mmhb/spa/devtest.csv", delimiter='\t')
df.sample(5)
# Out:
#         index                                       sentence_eng  \
# 17284  100895  I wonder what it'd be like to be an unmarried ...
# 12462   72786                 It is hard being a leftist spouse.
# 16550   96377         I have friends who are middle-class women.
# 23233  136868                    I used to be a country grandma.
# 18449  108620                      I like dyslexic grandmothers.
#
#       pattern_id_main noun_id_main desc_id_main    split both  \
# 17284             P16         N001       F_D200  devtest  NaN
# 12462             P11         N057       F_D302  devtest  NaN
# 16550             P15         N002       F_D406  devtest  NaN
# 23233             P21         N019       F_D230  devtest  NaN
# 18449             P17         N018       F_D012  devtest  NaN
#
#                                                 feminine masculine  \
# 17284  ['Me pregunto cómo sería ser una mujer soltera.']       NaN
# ...

# %%
df_both = df[df.gender_group == 'both']
df_both
# Out:
# Empty DataFrame
# Columns: [index, sentence_eng, pattern_id_main, noun_id_main, desc_id_main, split, both, feminine, masculine, both_count, feminine_count, masculine_count, lang, sentence_spa, translate_spa, translate_eng, gender_group]
# Index: []

# %%
df.gender_group.unique()
# Out:
# array(['feminine', 'masculine'], dtype=object)
